# %% [markdown]
# <a href="https://colab.research.google.com/github/ianara01/Park-Sangjin/blob/master/%EB%A9%8B%EC%82%AC_%ED%8C%8C%EC%9D%B4%EC%8D%AC%EB%B0%B1%EC%97%94%EB%93%9C12%EA%B8%B0_day12_%EC%9D%B4%EB%AF%B8%EC%A7%80_git_streamlit1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from PIL import Image

# %%
image = Image.open("a.webp")

# %%
image
# Out:
# <PIL.WebPImagePlugin.WebPImageFile image mode=RGB size=1000x666>

# %%
image.rotate(180)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x666>

# %%
image.convert("L")
# Out:
# <PIL.Image.Image image mode=L size=1000x666>

# %%
# left, top, right, bottom
image.crop((100, 100, 400, 400))
# Out:
# <PIL.Image.Image image mode=RGB size=300x300>

# %%
from PIL import Image, ImageDraw, ImageFont

# 이미지 열기
image = Image.open("a.webp")
draw = ImageDraw.Draw(image)
# 사용할 폰트 정의
#font = ImageFont.truetype("arial.ttf", size=45)
# 기본 폰트 사용
font = ImageFont.load_default()
# 이미지에 텍스트 추가 (x, y, message, fill=color, font=font)
draw.text((10, 10), "Hello, World!", fill="white", font=font)
# 텍스트가 추가된 이미지 저장
image.save("text_added.jpg")

# %%
from PIL import Image, ImageFilter

# 이미지에 가우시안 블러 필터 적용
blurred_image = image.filter(ImageFilter.BoxBlur(10))
# 필터가 적용된 이미지 저장
blurred_image.save("blurred.jpg")

# %%
from PIL import Image, ImageEnhance

# 대비 조정 객체 생성
enhancer = ImageEnhance.Contrast(image)
# 대비를 2로 증가
enhanced_image = enhancer.enhance(2)
# 대비가 증가된 이미지 저장
enhanced_image.save("enhanced_contrast.jpg")

# %%
import cv2

# 동영상 파일 열기
cap = cv2.VideoCapture("lion.mp4")  # cv2.VideoCapture(0) : 웹캠 접속시 숫자를 넣으면 됩니다.
edge_bool = False
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break
    # 그레이스케일 변환
    gray_img = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    # Canny edge detection 적용
    edges = cv2.Canny(image=gray_img, threshold1=100, threshold2=200)

    if edge_bool:
        image = edges
    else:
        image = frame
    cv2.imshow("Video", image)
    key = cv2.waitKey(1)
    if key == ord("q"):break
    elif key == ord("b"):
        edge_bool = not edge_bool


# 외부 자원은 반환
cap.release()
cv2.destroyAllWindows()
# Out:
# 97

# %% [markdown]
# # OpenCV를 이용해서 키 입력에 따라서 보이는 화면이 달라지도록 개발
# - 10:50 까지 해보겠습니다.
# - 디스코드에 스레드에 개발 코드 공유해 주세요
# - 위에 샘플은 canny edge로 되었는데 다른 이미지 처리를 반영해 보겠습니다.
# - 예) 흑백 이미지로 변환, 회전, ....

# %% [markdown]
# # 유튜브 영상 다운받기
# - youtube 받고자 하는 영상 틀기
# - 영상 주소를 변경( youtube 앞에 ss 두개 입력)
#  - www.youtube.com/xxxxx -> www.ssyoutube.com/xxxxx

# %%
import time

for i in range(5):
  print(i)
  time.sleep(1)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
def func(num):
  return num*2

# %%
func(4)
# Out:
# 8

# %%
def gen_func(num):
  for i in range(num):
    yield i

# %%
for ii in gen_func(5):
  print(ii)
  time.sleep(1)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
_LOREM_IPSUM = """
Lorem ipsum dolor sit amet, **consectetur adipiscing** elit, sed do eiusmod tempor
incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis
nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat.
"""

# %%
words = _LOREM_IPSUM.split(" ")

# %%
def word_gen( words ):
  for word in words:
    time.sleep(1)
    yield word

# %%
for w in word_gen(words):
  print(w)
# Out:
# Lorem
# ipsum
# dolor
# sit
# amet,
# **consectetur
# adipiscing**
# elit,
# sed
# do
# eiusmod
# tempor
# incididunt
# ut
# labore
# et
# dolore
# magna
# aliqua.
# Ut
# enim
# ad
# minim
# veniam,
# quis
# nostrud
# exercitation
# ullamco
# laboris
# nisi
# ut
# aliquip
# ex
# ea
# commodo
# consequat.

# %% [markdown]
# # 간단한 계산기 만들기: 두 숫자를 입력 받아 선택한 연산(더하기, 빼기, 곱하기, 나누기)의 결과를 보여주는 Streamlit 앱을 만드세요.
# - streamlit deploy로 배포해서 링크를 스레드에 올려주세요!
# - 2:50까지
# - 개발 절차
#  - streamlit 개발
#  - git push
#  - deploy 클릭
#  - 기본 설정으로 진행하고 링크 확인
